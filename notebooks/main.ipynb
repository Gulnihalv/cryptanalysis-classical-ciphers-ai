# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys
sys.path.append('/content/drive/MyDrive/Crypto-Project/src')

# %%
from raw_data_download import download_tr_wikipedia
download_tr_wikipedia()
